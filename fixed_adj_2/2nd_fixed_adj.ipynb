# %%
import numpy as np
import random
import networkx as nx
import pandas as pd
from numpy.random import uniform, randint
from node import EpidemicGraph, TransitionDiagram, calc_R0
from random import sample
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
paramet = {
        'alpha': [0.03, 0.06], # infect rate 
        'mu': [0.14, 0.14], # sleep s 
        'gamma': [0.35, 0.47], # rec rate 
        'lambda': [0.05, 0.32], # sleep I1 
        'kappa': [0.04, 0.31] # sleep I2    % [I2_s -> I2_a, I2_a -> I2_s]
    }
paramet = {
        'alpha': [0.2, 0.15], # infect rate 
        'mu': [0.04, 0.04], # sleep s 
        'gamma': [0.08, 0.05], # rec rate 
        'lambda': [0.1, 0.12], # sleep I1 
        'kappa': [0.09, 0.11] # sleep I2    % [I2_s -> I2_a, I2_a -> I2_s]
    }
N = 160
r = 1.5
number_subgraphs = 0
np.random.seed(315)  # structure
random.seed(6)       # infected

while number_subgraphs != 1:
    a = EpidemicGraph(N,r,paramet,I1_a=10, I2_a=10, grid_size=[7,7]) # net='Uniform Grid'
    number_subgraphs = len(list(nx.connected_component_subgraphs(a.G)))
    number_isolated_nodes = len(list(nx.isolates(a.G)))
    print(calc_R0(a.G, paramet), (number_subgraphs, number_isolated_nodes))

G = a.G
# a.run(300)
# a.G[0]
# asd = a.hist2pandas()
# asd1 = asd[['I1_a','I1_s','I2_a','I2_s']]/N
# asd1.plot()

pos = nx.get_node_attributes(G, 'position')
plt.figure(figsize=(10, 10))
nx.draw_networkx_edges(G, pos, alpha=0.4)
nx.draw_networkx_nodes(G, pos,
                       node_size=10,
                       cmap=plt.cm.Reds_r)
plt.show()
# Out:
# ((12.995643312533492+0j), (12.277165605500137+0j)) (1, 0)

# %%
# adjacency = pd.DataFrame(nx.adjacency_matrix(G).todense())
# adjacency.to_csv(f'adj_{G.graph["radius"]}.csv',index=False, header=False)
# pos = nx.get_node_attributes(G, 'position')
# pd.DataFrame(pos).to_csv(f'pos_{G.graph["radius"]}.csv',index=False, header=False)

# %%
def monte(n, r, paramet, nstep=100, I1_a=10, I2_a=10, grid_size=[30,30], net='Geometric Random'): # 'Geometric Random', 'Uniform Grid'
    for item in locals().items():
        print(item)
    listt = []
    for i in range(n):
        a = EpidemicGraph(N, r, paramet, I1_a=I1_a, I2_a=I1_a, grid_size=grid_size, net=net)
        a.run(nstep)
        listt.append(a.hist2pandas())
        number_subgraphs = len(list(nx.connected_component_subgraphs(a.G)))
        number_isolated_nodes = len(list(nx.isolates(a.G)))
        print(f'({i+1} {number_isolated_nodes}/{number_subgraphs} {calc_R0(a.G, paramet)})', end='\n')
    print()
    df = listt[0]
    del listt[0]
    for v in listt:
        df += v
    df /= n
    return df

def monte_load(n, a, nstep): # 'Geometric Random', 'Uniform Grid'
    for item in locals().items():
        print(item)
    listt = []
    for i in range(n):
        a.run(nstep)
        listt.append(a.hist2pandas())
        number_subgraphs = len(list(nx.connected_component_subgraphs(a.G)))
        number_isolated_nodes = len(list(nx.isolates(a.G)))
        print(f'({i+1} {number_isolated_nodes}/{number_subgraphs} {calc_R0(a.G, paramet)})', end='\n')
    print()
    df = listt[0]
    del listt[0]
    for v in listt:
        df += v
    df /= n
    return df, listt

N = 900
r=1.5
paramet = {
        'alpha': [0.25, 0.35], # infect rate 
        'mu': [0.04, 0.04], # sleep s 
        'gamma': [0.04, 0.35], # rec rate 
        'lambda': [0.06, 0.07], # sleep I1 
        'kappa': [0.05, 0.06] # sleep I2    % [I2_s -> I2_a, I2_a -> I2_s]
    }


setup = {'n':5, 
         'r':1.5, 
         'paramet': paramet,
         'nstep':300,
         'I1_a':50, 
         'I2_a':50, 
         'grid_size':[30,30]}
a = EpidemicGraph.load(N,r,paramet,I1_a=50, I2_a=50, grid_size=[30,30]) # net='Uniform Grid'



# rnd_monte = monte(net='Geometric Random', **setup)
rnd_monte, listt = monte_load(15, a, nstep=300)
rnd_monte.to_csv(f"monte_random_r={setup['r']}_{setup['n']}.csv", index=False)
asd1 = rnd_monte[['I1_a','I1_s','I2_a','I2_s']]
asd1.plot()
# Out:
# ('n', 15)
# ('a', <node.EpidemicGraph object at 0x000002519FBDC978>)
# ('nstep', 300)
# (1 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (2 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (3 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (4 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (5 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (6 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (7 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (8 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (9 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (10 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (11 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (12 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (13 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (14 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))
# (15 0/1 ((14.768639719734487+0j), (5.46431833375392+0j)))

# %%
uni_monte = monte(net='Uniform Grid', **setup)
uni_monte.to_csv(f'monte_uniform_r={setup["r"]}_{setup["n"]}.csv', index=False)
asd2 = uni_monte[['I1_a','I1_s','I2_a','I2_s']]/N
asd2.plot()
# Out:
# ('n', 5)
# ('r', 1.5)
# ('paramet', {'alpha': [0.25, 0.35], 'mu': [0.04, 0.04], 'gamma': [0.04, 0.35], 'lambda': [0.06, 0.07], 'kappa': [0.05, 0.06]})
# ('nstep', 300)
# ('I1_a', 50)
# ('I2_a', 50)
# ('grid_size', [30, 30])
# ('net', 'Uniform Grid')
# (1 0/1 ((9.56651951826436+0j), (3.510351233689536+0j)))
# (2 0/1 ((9.56651951826436+0j), (3.510351233689536+0j)))
# (3 0/1 ((9.56651951826436+0j), (3.510351233689536+0j)))
# (4 0/1 ((9.56651951826436+0j), (3.510351233689536+0j)))
# (5 0/1 ((9.56651951826436+0j), (3.510351233689536+0j)))

# %%
# print(sample(list(a.G[0]), len(a.G[0])))
# list(a.G[0])
len(list(nx.isolates(a.G)))
graphs = len(list(nx.connected_component_subgraphs(a.G)))
# Out:
# 126

# %%
r = 1.5

GG = 
pos = nx.get_node_attributes(GG, 'position')



for node in GG.nodes(data=True):
    print(node)
plt.figure(figsize=(10, 10))
nx.draw_networkx_edges(G, pos, alpha=0.4)
nx.draw_networkx_nodes(G, pos,
                       node_size=10,
                       cmap=plt.cm.Reds_r)
plt.show()
# Out:
# 20 20
# (0, {'position': array([22.0367834 , 24.43936678]), 'state': 'S_a'})
# (1, {'position': array([ 7.81768657, 14.19835388]), 'state': 'S_a'})
# (2, {'position': array([ 8.07644126, 10.45724285]), 'state': 'S_a'})
# (3, {'position': array([11.06624029, 23.67053869]), 'state': 'S_a'})
# (4, {'position': array([12.13916228, 25.52887157]), 'state': 'S_a'})
# (5, {'position': array([18.19568471, 22.14508356]), 'state': 'S_a'})
# (6, {'position': array([ 0.85498914, 16.12899904]), 'state': 'S_a'})
# (7, {'position': array([24.9865266 ,  0.64276874]), 'state': 'S_a'})
# (8, {'position': array([13.78593168, 15.80742778]), 'state': 'S_a'})
# (9, {'position': array([21.78362465,  1.76258415]), 'state': 'I2_a'})
# (10, {'position': array([14.38067374,  2.76530626]), 'state': 'S_a'})
# (11, {'position': array([28.28530876,  0.6704372 ]), 'state': 'S_a'})
# (12, {'position': array([29.71464217, 28.75865197]), 'state': 'S_a'})
# (13, {'position': array([22.7466407 , 25.13223807]), 'state': 'S_a'})
# (14, {'position': array([18.37879687,  8.38874393]), 'state': 'S_a'})
# (15, {'position': array([ 8.21749149, 16.48341121]), 'state': 'S_a'})
# (16, {'position': array([3.20687597, 7.02492323]), 'state': 'S_a'})
# (17, {'position': array([ 5.76918586, 11.69549599]), 'state': 'S_a'})
# (18, {'position': array([16.32426333, 18.74289882]), 'state': 'S_a'})
# (19, {'position': array([25.81871258, 18.58301502]), 'state': 'S_a'})
# (20, {'position': array([23.26810192,  1.98609655]), 'state': 'S_a'})
# (21, {'position': array([26.22557422, 27.3902538 ]), 'state': 'S_a'})
# (22, {'position': array([12.22505102, 21.45783196]), 'state': 'S_a'})
# (23, {'position': array([15.86537637, 15.47339403]), 'state': 'S_a'})
# (24, {'position': array([ 4.00599854, 17.49550008]), 'state': 'S_a'})
# (25, {'position': array([ 1.56653481, 28.46411397]), 'state': 'S_a'})
# (26, {'position': array([21.05246452, 11.80019903]), 'state': 'S_a'})
# (27, {'position': array([27.53428697, 26.33150098]), 'state': 'S_a'})
# (28, {'position': array([21.06131561, 22.43056736]), 'state': 'S_a'})
# (29, {'position': array([ 4.54151784, 17.34294316]), 'state': 'S_a'})
# (30, {'position': array([23.49065429,  0.33838844]), 'state': 'S_a'})
# (31, {'position': array([18.346204  ,  6.65692965]), 'state': 'S_a'})
# (32, {'position': array([11.71684444, 22.7602084 ]), 'state': 'S_a'})
# (33, {'position': array([ 9.24145067, 20.40648113]), 'state': 'S_a'})
# (34, {'position': array([17.0199931 , 26.76243064]), 'state': 'S_a'})
# (35, {'position': array([10.40773109, 11.35322075]), 'state': 'S_a'})
# (36, {'position': array([7.95913252, 6.19924881]), 'state': 'S_a'})
# (37, {'position': array([7.47306062, 2.1197668 ]), 'state': 'S_a'})
# (38, {'position': array([18.04474697,  7.72867338]), 'state': 'S_a'})
# (39, {'position': array([21.50799554,  9.70338636]), 'state': 'S_a'})
# (40, {'position': array([19.57180866, 16.40826543]), 'state': 'S_a'})
# (41, {'position': array([10.07383018, 28.90433175]), 'state': 'S_a'})
# (42, {'position': array([3.64109205, 8.54367558]), 'state': 'S_a'})
# (43, {'position': array([25.15043926, 19.0858818 ]), 'state': 'S_a'})
# (44, {'position': array([12.63567112, 10.55831307]), 'state': 'S_a'})
# (45, {'position': array([15.10437274,  2.94024672]), 'state': 'S_a'})
# (46, {'position': array([18.20443239, 24.52013329]), 'state': 'S_a'})
# (47, {'position': array([29.55031985, 23.73269427]), 'state': 'S_a'})
# (48, {'position': array([ 4.59067987, 22.95419202]), 'state': 'S_a'})
# (49, {'position': array([2.03759165, 2.24780641]), 'state': 'S_a'})
# (50, {'position': array([21.1573669 ,  8.44497925]), 'state': 'S_a'})
# (51, {'position': array([1.77435779, 8.27153888]), 'state': 'S_a'})
# (52, {'position': array([18.93597522, 15.61533574]), 'state': 'I2_a'})
# (53, {'position': array([28.99379663,  8.93533881]), 'state': 'S_a'})
# (54, {'position': array([29.10573963, 13.94975489]), 'state': 'S_a'})
# (55, {'position': array([23.59887445,  1.47726356]), 'state': 'S_a'})
# (56, {'position': array([ 3.90929237, 18.58230667]), 'state': 'S_a'})
# (57, {'position': array([ 6.96434978, 11.76666955]), 'state': 'S_a'})
# (58, {'position': array([21.73783103, 19.10359187]), 'state': 'S_a'})
# (59, {'position': array([25.56481876,  3.30150202]), 'state': 'S_a'})
# (60, {'position': array([8.99505987, 1.56363902]), 'state': 'S_a'})
# (61, {'position': array([12.82360163, 29.71563598]), 'state': 'S_a'})
# (62, {'position': array([2.16876226, 8.43007734]), 'state': 'S_a'})
# (63, {'position': array([28.35658405,  7.24981933]), 'state': 'S_a'})
# (64, {'position': array([ 1.21396122, 20.11556261]), 'state': 'S_a'})
# (65, {'position': array([18.53748155,  9.15673257]), 'state': 'S_a'})
# (66, {'position': array([8.22162729, 7.97633255]), 'state': 'I1_a'})
# (67, {'position': array([3.78752357, 9.86316465]), 'state': 'S_a'})
# (68, {'position': array([23.14788559, 25.98845866]), 'state': 'S_a'})
# (69, {'position': array([13.74000697, 24.05916761]), 'state': 'S_a'})
# (70, {'position': array([27.63916721, 11.37466049]), 'state': 'S_a'})
# (71, {'position': array([27.97032283,  9.27225971]), 'state': 'S_a'})
# (72, {'position': array([3.49830301, 1.7439927 ]), 'state': 'S_a'})
# (73, {'position': array([21.71650985,  4.97220639]), 'state': 'S_a'})
# (74, {'position': array([17.64356874, 11.64299396]), 'state': 'S_a'})
# (75, {'position': array([11.53860413, 21.83089096]), 'state': 'S_a'})
# (76, {'position': array([24.89345303, 16.5602054 ]), 'state': 'S_a'})
# (77, {'position': array([13.9649974 ,  1.75614885]), 'state': 'S_a'})
# (78, {'position': array([15.26834921, 29.16330804]), 'state': 'S_a'})
# (79, {'position': array([29.34889834, 22.81131387]), 'state': 'S_a'})
# (80, {'position': array([21.06060124, 12.8720111 ]), 'state': 'S_a'})
# (81, {'position': array([28.64622884, 24.99844304]), 'state': 'S_a'})
# (82, {'position': array([10.69266804,  7.67071481]), 'state': 'S_a'})
# (83, {'position': array([25.8681449 , 24.99772122]), 'state': 'S_a'})
# (84, {'position': array([0.81991363, 6.05866049]), 'state': 'S_a'})
# (85, {'position': array([25.51667806, 26.52896788]), 'state': 'S_a'})
# (86, {'position': array([2.62673224, 5.63203281]), 'state': 'S_a'})
# (87, {'position': array([25.82002821, 17.80278749]), 'state': 'S_a'})
# (88, {'position': array([19.35274828,  6.26016114]), 'state': 'S_a'})
# (89, {'position': array([19.22671349, 19.97576494]), 'state': 'S_a'})
# (90, {'position': array([4.18363754, 7.02501643]), 'state': 'S_a'})
# (91, {'position': array([ 0.66089108, 28.93127465]), 'state': 'S_a'})
# (92, {'position': array([3.90313529, 4.064951  ]), 'state': 'S_a'})
# (93, {'position': array([23.56617547, 26.31196323]), 'state': 'S_a'})
# (94, {'position': array([ 1.83585276, 11.11892711]), 'state': 'S_a'})
# (95, {'position': array([29.7343525 , 23.97480778]), 'state': 'S_a'})
# (96, {'position': array([19.68020558,  8.92540411]), 'state': 'S_a'})
# (97, {'position': array([ 9.7263929 , 12.29785386]), 'state': 'S_a'})
# (98, {'position': array([26.08067582,  1.22036161]), 'state': 'S_a'})
# (99, {'position': array([ 4.66040757, 17.04836418]), 'state': 'S_a'})
# (100, {'position': array([13.15052454, 20.09851701]), 'state': 'S_a'})
# (101, {'position': array([15.49768561, 12.23257653]), 'state': 'S_a'})
# (102, {'position': array([28.23349813, 17.15210198]), 'state': 'S_a'})
# (103, {'position': array([29.14564957, 10.4227089 ]), 'state': 'S_a'})
# (104, {'position': array([7.92919148, 1.74568273]), 'state': 'S_a'})
# (105, {'position': array([25.38794336, 15.30455058]), 'state': 'S_a'})
# (106, {'position': array([17.31094966, 23.57058525]), 'state': 'S_a'})
# (107, {'position': array([4.33859283, 4.67987975]), 'state': 'S_a'})
# (108, {'position': array([17.49317647, 23.8080425 ]), 'state': 'S_a'})
# (109, {'position': array([ 9.24795698, 21.57931251]), 'state': 'S_a'})
# (110, {'position': array([ 9.25294239, 15.54940459]), 'state': 'S_a'})
# (111, {'position': array([17.00398321,  4.71779787]), 'state': 'S_a'})
# (112, {'position': array([29.0608751 , 20.73238193]), 'state': 'S_a'})
# (113, {'position': array([13.86972302, 25.26752702]), 'state': 'S_a'})
# (114, {'position': array([11.48216594,  9.37004319]), 'state': 'S_a'})
# (115, {'position': array([23.18922615,  1.63992827]), 'state': 'S_a'})
# (116, {'position': array([14.61171617, 18.679136  ]), 'state': 'S_a'})
# (117, {'position': array([28.53915023, 16.83395339]), 'state': 'S_a'})
# (118, {'position': array([20.15953156, 18.22896721]), 'state': 'S_a'})
# (119, {'position': array([ 4.26338952, 17.6813209 ]), 'state': 'S_a'})
# (120, {'position': array([22.43236202,  1.22316837]), 'state': 'S_a'})
# (121, {'position': array([ 6.09880743, 12.40260893]), 'state': 'S_a'})
# (122, {'position': array([29.37600893, 26.44233844]), 'state': 'S_a'})
# (123, {'position': array([23.72352834, 14.93822722]), 'state': 'S_a'})
# (124, {'position': array([ 3.18738138, 10.83309755]), 'state': 'S_a'})
# (125, {'position': array([24.61404539, 24.79209373]), 'state': 'I2_a'})
# (126, {'position': array([ 4.56097154, 24.21008199]), 'state': 'S_a'})
# (127, {'position': array([18.18110024, 12.58655922]), 'state': 'S_a'})
# (128, {'position': array([24.37974515, 26.58863886]), 'state': 'S_a'})
# (129, {'position': array([11.88331568,  9.75126768]), 'state': 'S_a'})
# (130, {'position': array([3.11764826, 7.0533609 ]), 'state': 'S_a'})
# (131, {'position': array([20.88634088, 26.46163809]), 'state': 'S_a'})
# (132, {'position': array([13.43602987, 12.42807798]), 'state': 'S_a'})
# (133, {'position': array([18.00802263,  6.15164677]), 'state': 'S_a'})
# (134, {'position': array([27.19668119, 24.77892325]), 'state': 'S_a'})
# (135, {'position': array([11.65163684, 16.53624963]), 'state': 'S_a'})
# (136, {'position': array([ 6.33603245, 29.776386  ]), 'state': 'S_a'})
# (137, {'position': array([ 5.25273513, 29.32854473]), 'state': 'S_a'})
# (138, {'position': array([16.38466809, 28.20426492]), 'state': 'S_a'})
# (139, {'position': array([28.24784688, 21.82821011]), 'state': 'S_a'})
# (140, {'position': array([16.96384089,  8.10431489]), 'state': 'S_a'})
# (141, {'position': array([23.73237095, 16.16157403]), 'state': 'S_a'})
# (142, {'position': array([ 6.75622989, 25.60504552]), 'state': 'S_a'})
# (143, {'position': array([18.04847326, 14.95620155]), 'state': 'S_a'})
# (144, {'position': array([9.38722924, 5.79168539]), 'state': 'S_a'})
# (145, {'position': array([28.30597246, 27.61358051]), 'state': 'S_a'})
# (146, {'position': array([ 9.19198995, 19.94263719]), 'state': 'S_a'})
# (147, {'position': array([28.74028446, 23.67597061]), 'state': 'S_a'})
# (148, {'position': array([24.35441304,  2.97220435]), 'state': 'S_a'})
# (149, {'position': array([ 9.44126067, 28.84434509]), 'state': 'S_a'})
# (150, {'position': array([ 6.57935513, 20.33510613]), 'state': 'S_a'})
# (151, {'position': array([ 1.88139275, 10.65877049]), 'state': 'S_a'})
# (152, {'position': array([14.42994493,  4.50948009]), 'state': 'S_a'})
# (153, {'position': array([2.92624005, 7.95720239]), 'state': 'S_a'})
# (154, {'position': array([17.11722288, 24.2051273 ]), 'state': 'S_a'})
# (155, {'position': array([13.479805  ,  2.01243125]), 'state': 'S_a'})
# (156, {'position': array([18.13482214, 11.54673507]), 'state': 'S_a'})
# (157, {'position': array([14.65193344, 12.83691162]), 'state': 'S_a'})
# (158, {'position': array([27.93254217, 28.19690566]), 'state': 'S_a'})
# (159, {'position': array([12.77181833,  6.06605644]), 'state': 'S_a'})
# (160, {'position': array([ 8.34584335, 12.41323878]), 'state': 'S_a'})
# (161, {'position': array([28.50680238, 27.30973878]), 'state': 'S_a'})
# (162, {'position': array([27.33883044, 27.75293761]), 'state': 'S_a'})
# (163, {'position': array([1.44895396, 1.69645074]), 'state': 'S_a'})
# (164, {'position': array([23.56865061,  8.26779817]), 'state': 'S_a'})
# (165, {'position': array([26.26478335, 25.8226715 ]), 'state': 'S_a'})
# (166, {'position': array([12.77561937, 22.70110595]), 'state': 'S_a'})
# (167, {'position': array([13.24881716,  0.79110323]), 'state': 'S_a'})
# (168, {'position': array([ 0.8032804 , 23.07447015]), 'state': 'S_a'})
# (169, {'position': array([ 0.20440254, 19.73766552]), 'state': 'S_a'})
# (170, {'position': array([14.28728082, 12.18866349]), 'state': 'S_a'})
# (171, {'position': array([19.72622547,  9.74045179]), 'state': 'S_a'})
# (172, {'position': array([18.83385338, 12.7064402 ]), 'state': 'S_a'})
# (173, {'position': array([25.27960198, 24.32036957]), 'state': 'S_a'})
# (174, {'position': array([ 8.92588146, 29.97920428]), 'state': 'S_a'})
# (175, {'position': array([22.01705994, 20.05799746]), 'state': 'S_a'})
# (176, {'position': array([28.73018292, 18.38797794]), 'state': 'S_a'})
# (177, {'position': array([22.65391456, 10.42109374]), 'state': 'S_a'})
# (178, {'position': array([ 2.43115112, 16.25631484]), 'state': 'S_a'})
# (179, {'position': array([ 5.18926836, 22.10850894]), 'state': 'S_a'})
# (180, {'position': array([13.30994633, 15.30487489]), 'state': 'S_a'})
# (181, {'position': array([ 8.2345263 , 21.21402453]), 'state': 'S_a'})
# (182, {'position': array([ 2.16615207, 22.76745263]), 'state': 'S_a'})
# (183, {'position': array([25.13444197, 15.69377509]), 'state': 'S_a'})
# (184, {'position': array([18.57605641, 26.03646661]), 'state': 'I1_a'})
# (185, {'position': array([ 3.52145735, 13.75132489]), 'state': 'S_a'})
# (186, {'position': array([10.56223652,  9.28307684]), 'state': 'I1_a'})
# (187, {'position': array([5.16019536, 0.37406543]), 'state': 'S_a'})
# (188, {'position': array([14.63583846, 25.06303011]), 'state': 'S_a'})
# (189, {'position': array([17.17228915, 23.12458325]), 'state': 'S_a'})
# (190, {'position': array([12.87178122, 17.55639118]), 'state': 'S_a'})
# (191, {'position': array([24.93241478, 20.98229144]), 'state': 'S_a'})
# (192, {'position': array([3.42819468, 2.08664932]), 'state': 'S_a'})
# (193, {'position': array([27.64158941, 16.90986433]), 'state': 'S_a'})
# (194, {'position': array([ 0.88228881, 11.13078914]), 'state': 'S_a'})
# (195, {'position': array([ 8.04289971, 16.35222731]), 'state': 'S_a'})
# (196, {'position': array([ 6.94845883, 26.24891186]), 'state': 'S_a'})
# (197, {'position': array([29.57219607, 17.26201353]), 'state': 'S_a'})
# (198, {'position': array([24.73149717,  1.48334223]), 'state': 'S_a'})
# (199, {'position': array([ 3.83151219, 19.59334441]), 'state': 'S_a'})
# (200, {'position': array([23.03661213, 14.56707595]), 'state': 'S_a'})
# (201, {'position': array([4.33832588, 4.98495653]), 'state': 'S_a'})
# (202, {'position': array([11.66216248, 10.69218351]), 'state': 'S_a'})
# (203, {'position': array([14.5307109 ,  3.46138102]), 'state': 'S_a'})
# (204, {'position': array([ 2.87461241, 17.00410537]), 'state': 'I1_a'})
# (205, {'position': array([21.29999799, 29.2818137 ]), 'state': 'S_a'})
# (206, {'position': array([ 5.55449008, 27.24562625]), 'state': 'S_a'})
# (207, {'position': array([24.86334389, 29.16214838]), 'state': 'S_a'})
# (208, {'position': array([0.53459945, 2.167339  ]), 'state': 'S_a'})
# (209, {'position': array([26.64942285, 28.68780022]), 'state': 'S_a'})
# (210, {'position': array([ 6.89158526, 10.2038712 ]), 'state': 'S_a'})
# (211, {'position': array([20.78137713,  7.93375677]), 'state': 'S_a'})
# (212, {'position': array([28.20665411,  0.15403905]), 'state': 'S_a'})
# (213, {'position': array([7.80661359, 0.9501687 ]), 'state': 'S_a'})
# (214, {'position': array([ 1.23679258, 15.04358239]), 'state': 'S_a'})
# (215, {'position': array([22.31390563,  8.19752588]), 'state': 'S_a'})
# (216, {'position': array([ 0.19532476, 17.49131758]), 'state': 'S_a'})
# (217, {'position': array([15.48201188, 15.99048908]), 'state': 'S_a'})
# (218, {'position': array([ 2.66103143, 11.6751522 ]), 'state': 'S_a'})
# (219, {'position': array([ 7.29463509, 21.26278871]), 'state': 'S_a'})
# (220, {'position': array([1.61874286, 1.70402048]), 'state': 'S_a'})
# (221, {'position': array([ 1.31305902, 25.07177561]), 'state': 'S_a'})
# (222, {'position': array([2.44915586, 6.63259224]), 'state': 'S_a'})
# (223, {'position': array([ 5.54107005, 10.7458495 ]), 'state': 'S_a'})
# (224, {'position': array([2.99605821, 5.77866427]), 'state': 'I2_a'})
# (225, {'position': array([24.99779594, 29.71112367]), 'state': 'S_a'})
# (226, {'position': array([24.09933187, 11.22482943]), 'state': 'S_a'})
# (227, {'position': array([ 3.97852781, 21.41163676]), 'state': 'S_a'})
# (228, {'position': array([20.24033179, 21.98520707]), 'state': 'S_a'})
# (229, {'position': array([16.52843715,  5.53203047]), 'state': 'S_a'})
# (230, {'position': array([22.31684598,  0.85641414]), 'state': 'S_a'})
# (231, {'position': array([25.74427359,  0.09106722]), 'state': 'S_a'})
# (232, {'position': array([ 8.63334452, 22.46709514]), 'state': 'S_a'})
# (233, {'position': array([25.26882082, 28.71898458]), 'state': 'S_a'})
# (234, {'position': array([15.48659503,  0.75367148]), 'state': 'S_a'})
# (235, {'position': array([11.78413317, 11.87433564]), 'state': 'S_a'})
# (236, {'position': array([19.11255132,  9.81971541]), 'state': 'S_a'})
# (237, {'position': array([10.76712625, 17.11168086]), 'state': 'S_a'})
# (238, {'position': array([11.15529623,  3.86914018]), 'state': 'S_a'})
# (239, {'position': array([19.81578728, 25.75688417]), 'state': 'S_a'})
# (240, {'position': array([0.98070117, 5.93791821]), 'state': 'S_a'})
# (241, {'position': array([ 3.28634837, 20.25456316]), 'state': 'S_a'})
# (242, {'position': array([14.55063732, 11.9647967 ]), 'state': 'S_a'})
# (243, {'position': array([9.71446702, 0.27524879]), 'state': 'S_a'})
# (244, {'position': array([15.79350335, 18.42529241]), 'state': 'S_a'})
# (245, {'position': array([12.34700707, 22.71790647]), 'state': 'S_a'})
# (246, {'position': array([18.99525885, 25.41353081]), 'state': 'S_a'})
# (247, {'position': array([2.74834458, 7.1968246 ]), 'state': 'S_a'})
# (248, {'position': array([26.51058223, 14.58883287]), 'state': 'S_a'})
# (249, {'position': array([9.70820899, 9.77452736]), 'state': 'S_a'})
# (250, {'position': array([ 7.19672503, 10.76162834]), 'state': 'S_a'})
# (251, {'position': array([10.58010767,  3.39129262]), 'state': 'S_a'})
# (252, {'position': array([14.06732152, 10.81119082]), 'state': 'S_a'})
# (253, {'position': array([17.36102567,  3.49841378]), 'state': 'S_a'})
# (254, {'position': array([16.9683373 ,  9.56521676]), 'state': 'S_a'})
# (255, {'position': array([15.70090216,  4.9074298 ]), 'state': 'S_a'})
# (256, {'position': array([13.17383563, 11.47163699]), 'state': 'S_a'})
# (257, {'position': array([28.05396899,  6.53502668]), 'state': 'S_a'})
# (258, {'position': array([24.1030797,  9.8612138]), 'state': 'S_a'})
# (259, {'position': array([22.29008107, 23.59319775]), 'state': 'S_a'})
# (260, {'position': array([ 9.7739408 , 18.62745446]), 'state': 'S_a'})
# (261, {'position': array([13.44804135, 20.16825604]), 'state': 'S_a'})
# (262, {'position': array([2.39258079, 5.67658187]), 'state': 'S_a'})
# (263, {'position': array([14.38947764, 20.75299163]), 'state': 'S_a'})
# (264, {'position': array([12.08119408, 23.41637846]), 'state': 'S_a'})
# (265, {'position': array([21.72692222, 26.31268557]), 'state': 'S_a'})
# (266, {'position': array([22.54529413, 12.82000015]), 'state': 'S_a'})
# (267, {'position': array([27.5111904 ,  7.11616094]), 'state': 'S_a'})
# (268, {'position': array([25.05768555, 12.96369029]), 'state': 'S_a'})
# (269, {'position': array([20.32396313,  4.58507399]), 'state': 'S_a'})
# (270, {'position': array([8.14352625, 2.29765547]), 'state': 'S_a'})
# (271, {'position': array([24.18231225, 27.76990631]), 'state': 'S_a'})
# (272, {'position': array([8.92246498, 8.35995492]), 'state': 'S_a'})
# (273, {'position': array([ 8.31343507, 21.46277014]), 'state': 'S_a'})
# (274, {'position': array([19.68308898, 10.91774498]), 'state': 'S_a'})
# (275, {'position': array([ 0.90135376, 12.34251247]), 'state': 'S_a'})
# (276, {'position': array([ 6.89316186, 20.27727312]), 'state': 'S_a'})
# (277, {'position': array([10.43114477, 24.44843601]), 'state': 'S_a'})
# (278, {'position': array([14.02289651,  4.31208356]), 'state': 'S_a'})
# (279, {'position': array([12.97871351, 20.32316018]), 'state': 'S_a'})
# (280, {'position': array([2.81709043, 8.43773008]), 'state': 'S_a'})
# (281, {'position': array([14.49752576, 13.48453534]), 'state': 'I1_a'})
# (282, {'position': array([ 4.23047585, 18.96899971]), 'state': 'S_a'})
# (283, {'position': array([10.04009793, 22.7922343 ]), 'state': 'S_a'})
# (284, {'position': array([12.45120938,  2.07094163]), 'state': 'S_a'})
# (285, {'position': array([2.2473592 , 1.39010567]), 'state': 'S_a'})
# (286, {'position': array([28.87443656,  3.11811853]), 'state': 'S_a'})
# (287, {'position': array([ 8.40601016, 17.58460517]), 'state': 'S_a'})
# (288, {'position': array([6.29737258, 3.41088877]), 'state': 'S_a'})
# (289, {'position': array([12.91725787, 23.8431515 ]), 'state': 'S_a'})
# (290, {'position': array([20.75117967,  7.13777875]), 'state': 'S_a'})
# (291, {'position': array([1.80896119, 1.36708195]), 'state': 'S_a'})
# (292, {'position': array([16.96990888, 13.59637887]), 'state': 'S_a'})
# (293, {'position': array([4.1566559 , 3.77288576]), 'state': 'S_a'})
# (294, {'position': array([25.3803454 ,  1.73739538]), 'state': 'S_a'})
# (295, {'position': array([ 4.91520841, 15.09610649]), 'state': 'S_a'})
# (296, {'position': array([20.49630148, 25.28499054]), 'state': 'S_a'})
# (297, {'position': array([20.9326889 , 29.25795608]), 'state': 'S_a'})
# (298, {'position': array([25.15532425,  4.25683587]), 'state': 'S_a'})
# (299, {'position': array([15.61459926,  1.17817173]), 'state': 'S_a'})
# (300, {'position': array([24.89278264, 10.75906856]), 'state': 'S_a'})
# (301, {'position': array([2.92710878, 1.04799774]), 'state': 'S_a'})
# (302, {'position': array([25.33119813,  2.71496333]), 'state': 'S_a'})
# (303, {'position': array([26.4149405 ,  9.04657693]), 'state': 'S_a'})
# (304, {'position': array([20.12888685, 20.55187096]), 'state': 'S_a'})
# (305, {'position': array([ 3.37297646, 26.09702308]), 'state': 'S_a'})
# (306, {'position': array([ 3.56824466, 13.3554897 ]), 'state': 'S_a'})
# (307, {'position': array([12.55897363, 19.1258191 ]), 'state': 'S_a'})
# (308, {'position': array([17.36460872, 18.78566633]), 'state': 'S_a'})
# (309, {'position': array([ 4.21403269, 10.38910678]), 'state': 'S_a'})
# (310, {'position': array([ 3.66061669, 12.57529884]), 'state': 'S_a'})
# (311, {'position': array([21.23337318, 21.94638546]), 'state': 'S_a'})
# (312, {'position': array([23.75198224, 20.51149421]), 'state': 'S_a'})
# (313, {'position': array([11.0730999 , 24.82737591]), 'state': 'I2_a'})
# (314, {'position': array([ 9.78014592, 28.46678348]), 'state': 'S_a'})
# (315, {'position': array([24.26021295, 24.69327337]), 'state': 'S_a'})
# (316, {'position': array([3.72051915, 4.08990198]), 'state': 'S_a'})
# (317, {'position': array([17.66960432, 27.99324401]), 'state': 'S_a'})
# (318, {'position': array([ 4.17291917, 14.2194532 ]), 'state': 'S_a'})
# (319, {'position': array([ 8.26361948, 25.64901692]), 'state': 'S_a'})
# (320, {'position': array([ 3.04499029, 21.90388824]), 'state': 'S_a'})
# (321, {'position': array([14.65672092,  4.11271249]), 'state': 'S_a'})
# (322, {'position': array([10.36259473, 11.84906816]), 'state': 'S_a'})
# (323, {'position': array([15.51640455, 12.82693019]), 'state': 'S_a'})
# (324, {'position': array([20.50304412, 16.31077244]), 'state': 'S_a'})
# (325, {'position': array([ 3.110643  , 15.84411428]), 'state': 'S_a'})
# (326, {'position': array([17.85996627, 12.21970593]), 'state': 'S_a'})
# (327, {'position': array([22.23609893,  5.75439041]), 'state': 'S_a'})
# (328, {'position': array([29.89240672, 17.15668674]), 'state': 'S_a'})
# (329, {'position': array([27.17590284,  1.3910365 ]), 'state': 'S_a'})
# (330, {'position': array([ 4.60335884, 20.5842707 ]), 'state': 'S_a'})
# (331, {'position': array([12.90193078, 22.76017349]), 'state': 'S_a'})
# (332, {'position': array([20.71838418, 26.50101764]), 'state': 'S_a'})
# (333, {'position': array([ 9.13917703, 11.53914086]), 'state': 'S_a'})
# (334, {'position': array([ 5.8797334 , 19.03522365]), 'state': 'S_a'})
# (335, {'position': array([16.77950219, 19.03652803]), 'state': 'S_a'})
# (336, {'position': array([25.95260863, 16.6878297 ]), 'state': 'S_a'})
# (337, {'position': array([25.83239141, 16.10498751]), 'state': 'S_a'})
# (338, {'position': array([11.59909934, 10.35362714]), 'state': 'S_a'})
# (339, {'position': array([22.62336653, 16.79653989]), 'state': 'S_a'})
# (340, {'position': array([29.40908588, 14.38299937]), 'state': 'I2_a'})
# (341, {'position': array([16.54116873,  8.88785495]), 'state': 'S_a'})
# (342, {'position': array([19.13755915,  2.63178707]), 'state': 'S_a'})
# (343, {'position': array([23.78105513, 11.17487235]), 'state': 'S_a'})
# (344, {'position': array([ 9.81677553, 27.24778963]), 'state': 'S_a'})
# (345, {'position': array([16.46880277,  4.23106574]), 'state': 'S_a'})
# (346, {'position': array([22.51022106, 17.08536941]), 'state': 'S_a'})
# (347, {'position': array([3.85905371, 8.56757907]), 'state': 'S_a'})
# (348, {'position': array([ 4.7467408 , 16.71817148]), 'state': 'S_a'})
# (349, {'position': array([15.40738914, 18.41458338]), 'state': 'S_a'})
# (350, {'position': array([ 8.23486064, 22.14682308]), 'state': 'S_a'})
# (351, {'position': array([26.32394715, 15.87762537]), 'state': 'S_a'})
# (352, {'position': array([7.89909541, 3.39648539]), 'state': 'S_a'})
# (353, {'position': array([23.44567855, 20.4152965 ]), 'state': 'S_a'})
# (354, {'position': array([24.24168926,  0.80089457]), 'state': 'S_a'})
# (355, {'position': array([20.11801609, 15.20617105]), 'state': 'S_a'})
# (356, {'position': array([22.88998559, 10.55649014]), 'state': 'S_a'})
# (357, {'position': array([10.19234134,  3.98575492]), 'state': 'S_a'})
# (358, {'position': array([24.53909924, 22.68466918]), 'state': 'S_a'})
# (359, {'position': array([12.26772412,  1.45907814]), 'state': 'S_a'})
# (360, {'position': array([17.42243927, 11.50659839]), 'state': 'S_a'})
# (361, {'position': array([5.06957215, 9.27114202]), 'state': 'S_a'})
# (362, {'position': array([22.61784403, 29.94188189]), 'state': 'S_a'})
# (363, {'position': array([12.44786101, 13.21478484]), 'state': 'S_a'})
# (364, {'position': array([28.32130974, 19.67470116]), 'state': 'S_a'})
# (365, {'position': array([ 9.96806325, 26.5940833 ]), 'state': 'S_a'})
# (366, {'position': array([25.19987213, 23.81795204]), 'state': 'S_a'})
# (367, {'position': array([25.57220083,  1.99204253]), 'state': 'S_a'})
# (368, {'position': array([29.59614074,  6.42322205]), 'state': 'S_a'})
# (369, {'position': array([ 5.43080963, 13.11203453]), 'state': 'S_a'})
# (370, {'position': array([ 8.55797423, 23.27627   ]), 'state': 'S_a'})
# (371, {'position': array([10.35126599, 27.35258309]), 'state': 'S_a'})
# (372, {'position': array([29.57125387, 25.03352993]), 'state': 'S_a'})
# (373, {'position': array([ 8.12942088, 26.97230765]), 'state': 'S_a'})
# (374, {'position': array([27.21356389, 24.27314609]), 'state': 'S_a'})
# (375, {'position': array([11.1361724 , 22.62320792]), 'state': 'S_a'})
# (376, {'position': array([15.03518022,  0.61097673]), 'state': 'S_a'})
# (377, {'position': array([18.52058892, 10.72750388]), 'state': 'S_a'})
# (378, {'position': array([25.07171118, 10.4107987 ]), 'state': 'S_a'})
# (379, {'position': array([28.10564695,  5.38619175]), 'state': 'S_a'})
# (380, {'position': array([12.76147746,  4.48522531]), 'state': 'S_a'})
# (381, {'position': array([13.24410055, 18.94414954]), 'state': 'S_a'})
# (382, {'position': array([8.02632156, 3.2008569 ]), 'state': 'S_a'})
# (383, {'position': array([24.4651538 ,  3.83325265]), 'state': 'S_a'})
# (384, {'position': array([ 5.4808743 , 29.12275012]), 'state': 'S_a'})
# (385, {'position': array([25.85594797, 10.31571694]), 'state': 'S_a'})
# (386, {'position': array([17.80507308, 20.37133422]), 'state': 'S_a'})
# (387, {'position': array([ 1.58401566, 14.66403983]), 'state': 'S_a'})
# (388, {'position': array([ 7.65848086, 17.47935543]), 'state': 'S_a'})
# (389, {'position': array([12.57635732, 25.50253653]), 'state': 'S_a'})
# (390, {'position': array([16.2985586 , 23.66487587]), 'state': 'S_a'})
# (391, {'position': array([ 5.93801274, 23.56097798]), 'state': 'S_a'})
# (392, {'position': array([12.4402792 , 14.16382082]), 'state': 'S_a'})
# (393, {'position': array([25.69939341,  5.50935489]), 'state': 'S_a'})
# (394, {'position': array([13.19819263,  5.6699371 ]), 'state': 'S_a'})
# (395, {'position': array([24.92974074,  2.01841945]), 'state': 'S_a'})
# (396, {'position': array([22.39310356,  8.23663065]), 'state': 'I2_a'})
# (397, {'position': array([6.10148352e-03, 2.75167399e+01]), 'state': 'S_a'})
# (398, {'position': array([27.36578644, 21.15403628]), 'state': 'S_a'})
# (399, {'position': array([19.26619706,  9.98334622]), 'state': 'S_a'})
# (400, {'position': array([21.68318632, 23.04662643]), 'state': 'S_a'})
# (401, {'position': array([23.02384455,  0.63629765]), 'state': 'S_a'})
# (402, {'position': array([22.90355356, 16.19658357]), 'state': 'S_a'})
# (403, {'position': array([10.41756118, 17.09589642]), 'state': 'S_a'})
# (404, {'position': array([26.14246744, 12.83728684]), 'state': 'S_a'})
# (405, {'position': array([ 7.21800098, 16.78163969]), 'state': 'S_a'})
# (406, {'position': array([22.97216156,  3.7167877 ]), 'state': 'S_a'})
# (407, {'position': array([11.77106691, 22.52904303]), 'state': 'S_a'})
# (408, {'position': array([29.45738733, 13.30410344]), 'state': 'I2_a'})
# (409, {'position': array([22.41208402,  3.94017834]), 'state': 'S_a'})
# (410, {'position': array([ 3.39201057, 25.81262552]), 'state': 'S_a'})
# (411, {'position': array([18.34707351, 17.90130753]), 'state': 'S_a'})
# (412, {'position': array([12.699908 , 23.7362109]), 'state': 'S_a'})
# (413, {'position': array([28.0053743 , 23.36327141]), 'state': 'S_a'})
# (414, {'position': array([ 2.01977702, 12.65807881]), 'state': 'S_a'})
# (415, {'position': array([29.3550088 ,  9.25851884]), 'state': 'S_a'})
# (416, {'position': array([1.41576766, 3.94458524]), 'state': 'S_a'})
# (417, {'position': array([ 0.89887007, 26.52350611]), 'state': 'S_a'})
# (418, {'position': array([ 3.92017177, 10.93998135]), 'state': 'I1_a'})
# (419, {'position': array([15.98516439, 28.90575917]), 'state': 'S_a'})
# (420, {'position': array([13.63575885, 27.09666526]), 'state': 'S_a'})
# (421, {'position': array([14.08810007,  7.29316022]), 'state': 'S_a'})
# (422, {'position': array([2.25842543, 0.93363299]), 'state': 'S_a'})
# (423, {'position': array([15.75015934,  5.46509619]), 'state': 'S_a'})
# (424, {'position': array([21.24343306,  7.43812279]), 'state': 'S_a'})
# (425, {'position': array([19.3920065 , 11.23184817]), 'state': 'S_a'})
# (426, {'position': array([17.96430273,  7.76971978]), 'state': 'S_a'})
# (427, {'position': array([14.95792235, 18.95799324]), 'state': 'S_a'})
# (428, {'position': array([ 3.37663295, 22.14365297]), 'state': 'S_a'})
# (429, {'position': array([10.1898003 ,  5.08934978]), 'state': 'S_a'})
# (430, {'position': array([11.69665238, 16.11815602]), 'state': 'S_a'})
# (431, {'position': array([14.9573626 , 27.14894008]), 'state': 'S_a'})
# (432, {'position': array([19.71332436, 11.3372625 ]), 'state': 'S_a'})
# (433, {'position': array([ 9.76485326, 18.45882955]), 'state': 'S_a'})
# (434, {'position': array([22.95610185, 17.53613005]), 'state': 'S_a'})
# (435, {'position': array([2.06651114, 4.83436346]), 'state': 'S_a'})
# (436, {'position': array([ 6.60744194, 26.86752457]), 'state': 'S_a'})
# (437, {'position': array([14.58709913,  1.06180523]), 'state': 'I1_a'})
# (438, {'position': array([21.44142208, 24.2795155 ]), 'state': 'S_a'})
# (439, {'position': array([ 9.7752884 , 16.20677177]), 'state': 'S_a'})
# (440, {'position': array([ 8.29180636, 18.84618981]), 'state': 'S_a'})
# (441, {'position': array([26.06685823,  6.66307517]), 'state': 'S_a'})
# (442, {'position': array([19.33173325,  1.24693286]), 'state': 'S_a'})
# (443, {'position': array([ 7.15077249, 28.02589448]), 'state': 'S_a'})
# (444, {'position': array([14.49627857,  6.74796183]), 'state': 'S_a'})
# (445, {'position': array([23.75738161,  6.44148083]), 'state': 'S_a'})
# (446, {'position': array([24.39125612, 14.05692662]), 'state': 'S_a'})
# (447, {'position': array([9.11214765, 0.1106168 ]), 'state': 'S_a'})
# (448, {'position': array([16.39854068,  4.23382045]), 'state': 'S_a'})
# (449, {'position': array([20.43250403, 28.12003887]), 'state': 'S_a'})
# (450, {'position': array([15.45838531,  0.94793656]), 'state': 'S_a'})
# (451, {'position': array([10.7165243 , 27.63378028]), 'state': 'S_a'})
# (452, {'position': array([1.57806598, 1.04920718]), 'state': 'S_a'})
# (453, {'position': array([26.32545636, 17.84578723]), 'state': 'S_a'})
# (454, {'position': array([19.27944356, 14.51710097]), 'state': 'S_a'})
# (455, {'position': array([10.41658376, 28.00474792]), 'state': 'S_a'})
# (456, {'position': array([ 8.42777237, 13.43704603]), 'state': 'S_a'})
# (457, {'position': array([19.52142742,  4.63372256]), 'state': 'S_a'})
# (458, {'position': array([18.94567415,  1.12247757]), 'state': 'S_a'})
# (459, {'position': array([ 2.42630277, 15.46262346]), 'state': 'S_a'})
# (460, {'position': array([14.17788277,  6.29116531]), 'state': 'S_a'})
# (461, {'position': array([15.68231917, 13.41947161]), 'state': 'S_a'})
# (462, {'position': array([24.09384863,  8.35905174]), 'state': 'S_a'})
# (463, {'position': array([19.02787022, 29.88544808]), 'state': 'S_a'})
# (464, {'position': array([11.5274338 ,  0.44081774]), 'state': 'S_a'})
# (465, {'position': array([ 6.41164117, 22.52022092]), 'state': 'S_a'})
# (466, {'position': array([ 9.82948869, 28.5006522 ]), 'state': 'S_a'})
# (467, {'position': array([18.74759053,  3.14674116]), 'state': 'S_a'})
# (468, {'position': array([19.19068272, 26.1913035 ]), 'state': 'S_a'})
# (469, {'position': array([18.70710281,  7.7533228 ]), 'state': 'S_a'})
# (470, {'position': array([ 4.53499448, 14.22185585]), 'state': 'S_a'})
# (471, {'position': array([0.81593573, 5.1823358 ]), 'state': 'S_a'})
# (472, {'position': array([ 8.35511108, 29.3517589 ]), 'state': 'S_a'})
# (473, {'position': array([26.15444935, 27.69246986]), 'state': 'S_a'})
# (474, {'position': array([24.39397915,  2.52775225]), 'state': 'S_a'})
# (475, {'position': array([ 1.22527973, 27.8274848 ]), 'state': 'I1_a'})
# (476, {'position': array([8.11282632, 2.92983439]), 'state': 'S_a'})
# (477, {'position': array([ 9.55793382, 28.2231826 ]), 'state': 'I1_a'})
# (478, {'position': array([27.30354852, 24.4571305 ]), 'state': 'S_a'})
# (479, {'position': array([ 2.10127242, 12.80168201]), 'state': 'S_a'})
# (480, {'position': array([ 1.96899662, 25.78889462]), 'state': 'S_a'})
# (481, {'position': array([ 9.15073748, 21.49317124]), 'state': 'S_a'})
# (482, {'position': array([13.78282217,  6.47196623]), 'state': 'S_a'})
# (483, {'position': array([25.66967825, 24.07837467]), 'state': 'S_a'})
# (484, {'position': array([13.00118199,  8.40028593]), 'state': 'S_a'})
# (485, {'position': array([ 6.76837286, 12.01292742]), 'state': 'S_a'})
# (486, {'position': array([25.89598671,  3.55505688]), 'state': 'S_a'})
# (487, {'position': array([ 8.780374  , 17.79380417]), 'state': 'I2_a'})
# (488, {'position': array([ 4.72310287, 13.15286276]), 'state': 'S_a'})
# (489, {'position': array([28.69637159,  2.15360555]), 'state': 'S_a'})
# (490, {'position': array([11.56960757, 11.97470268]), 'state': 'S_a'})
# (491, {'position': array([0.59175992, 1.34127259]), 'state': 'S_a'})
# (492, {'position': array([3.35445216, 5.16810862]), 'state': 'S_a'})
# (493, {'position': array([14.40544393, 17.57730508]), 'state': 'S_a'})
# (494, {'position': array([25.12717671, 14.48381693]), 'state': 'S_a'})
# (495, {'position': array([17.73093192, 25.25285006]), 'state': 'S_a'})
# (496, {'position': array([ 1.66814255, 25.41471416]), 'state': 'S_a'})
# (497, {'position': array([26.49913387,  5.97179082]), 'state': 'S_a'})
# (498, {'position': array([22.1530293 , 13.94537083]), 'state': 'I2_a'})
# (499, {'position': array([ 3.13568883, 26.42383821]), 'state': 'S_a'})
# (500, {'position': array([16.10757576, 17.05863261]), 'state': 'I2_a'})
# (501, {'position': array([ 8.49751353, 22.15868666]), 'state': 'I1_a'})
# (502, {'position': array([9.09265508, 9.43467346]), 'state': 'S_a'})
# (503, {'position': array([ 1.86524217, 15.61747922]), 'state': 'S_a'})
# (504, {'position': array([23.32555661, 22.00726171]), 'state': 'S_a'})
# (505, {'position': array([4.55145077, 0.54994791]), 'state': 'S_a'})
# (506, {'position': array([ 2.97155845, 10.49154846]), 'state': 'S_a'})
# (507, {'position': array([14.90441615, 10.42575641]), 'state': 'S_a'})
# (508, {'position': array([15.69061833, 29.08882666]), 'state': 'S_a'})
# (509, {'position': array([20.88645287, 13.22782922]), 'state': 'S_a'})
# (510, {'position': array([ 6.18858826, 17.11964478]), 'state': 'S_a'})
# (511, {'position': array([25.41227188, 10.07401215]), 'state': 'S_a'})
# (512, {'position': array([11.96631813, 29.78173413]), 'state': 'S_a'})
# (513, {'position': array([24.92176635,  3.57060958]), 'state': 'S_a'})
# (514, {'position': array([17.86745921,  6.15787305]), 'state': 'S_a'})
# (515, {'position': array([ 8.1518086 , 21.68124579]), 'state': 'S_a'})
# (516, {'position': array([11.94375837, 12.32696041]), 'state': 'S_a'})
# (517, {'position': array([ 0.56814296, 21.4306633 ]), 'state': 'S_a'})
# (518, {'position': array([19.3824612 , 12.98882979]), 'state': 'S_a'})
# (519, {'position': array([5.81340506, 5.38646114]), 'state': 'S_a'})
# (520, {'position': array([17.3904091 , 19.53133453]), 'state': 'S_a'})
# (521, {'position': array([15.92399086, 24.76558785]), 'state': 'S_a'})
# (522, {'position': array([ 2.55020085, 16.1166309 ]), 'state': 'S_a'})
# (523, {'position': array([ 3.51967542, 12.76528975]), 'state': 'S_a'})
# (524, {'position': array([ 2.38428356, 20.45605847]), 'state': 'S_a'})
# (525, {'position': array([14.50280469,  5.59335887]), 'state': 'S_a'})
# (526, {'position': array([9.36487299, 8.78049331]), 'state': 'S_a'})
# (527, {'position': array([15.01265493, 17.13415143]), 'state': 'S_a'})
# (528, {'position': array([17.65023942,  8.89957006]), 'state': 'S_a'})
# (529, {'position': array([2.5324346 , 5.44431093]), 'state': 'S_a'})
# (530, {'position': array([13.24982905, 17.45447298]), 'state': 'S_a'})
# (531, {'position': array([23.18935155,  0.23276148]), 'state': 'S_a'})
# (532, {'position': array([18.32445584, 19.58214488]), 'state': 'S_a'})
# (533, {'position': array([18.39734362, 27.41086499]), 'state': 'S_a'})
# (534, {'position': array([22.27642557, 19.40592697]), 'state': 'S_a'})
# (535, {'position': array([ 5.00694238, 15.23472488]), 'state': 'S_a'})
# (536, {'position': array([14.63228136,  4.97633358]), 'state': 'S_a'})
# (537, {'position': array([21.46130479, 15.31395402]), 'state': 'S_a'})
# (538, {'position': array([ 1.9403543, 21.3780041]), 'state': 'S_a'})
# (539, {'position': array([27.83706312, 11.01451696]), 'state': 'S_a'})
# (540, {'position': array([19.44731942, 14.75165759]), 'state': 'S_a'})
# (541, {'position': array([19.08665835, 11.22218553]), 'state': 'I1_a'})
# (542, {'position': array([18.2171182 , 20.15969772]), 'state': 'S_a'})
# (543, {'position': array([19.18538402, 17.53861391]), 'state': 'S_a'})
# (544, {'position': array([ 1.15335249, 18.15206664]), 'state': 'S_a'})
# (545, {'position': array([15.84578766,  5.12679777]), 'state': 'S_a'})
# (546, {'position': array([ 2.11951921, 16.06840268]), 'state': 'S_a'})
# (547, {'position': array([1.54626991, 2.06194161]), 'state': 'S_a'})
# (548, {'position': array([18.00041906, 26.62214269]), 'state': 'S_a'})
# (549, {'position': array([10.83244958,  8.95598918]), 'state': 'S_a'})
# (550, {'position': array([ 8.90956118, 11.4786994 ]), 'state': 'S_a'})
# (551, {'position': array([29.06369345, 10.97700533]), 'state': 'S_a'})
# (552, {'position': array([0.76819672, 9.21268403]), 'state': 'S_a'})
# (553, {'position': array([13.44874857, 21.44394137]), 'state': 'S_a'})
# (554, {'position': array([1.50769688, 1.13465347]), 'state': 'S_a'})
# (555, {'position': array([ 3.85595169, 20.42463969]), 'state': 'S_a'})
# (556, {'position': array([20.75669225, 29.86216382]), 'state': 'S_a'})
# (557, {'position': array([ 3.05186486, 18.8227075 ]), 'state': 'S_a'})
# (558, {'position': array([6.34715409, 9.49727146]), 'state': 'S_a'})
# (559, {'position': array([ 9.50847945, 25.78264385]), 'state': 'S_a'})
# (560, {'position': array([ 1.30331695, 19.63764114]), 'state': 'S_a'})
# (561, {'position': array([ 6.65319187, 19.48262868]), 'state': 'S_a'})
# (562, {'position': array([23.97446184, 19.45830569]), 'state': 'S_a'})
# (563, {'position': array([19.07374619, 21.38243458]), 'state': 'S_a'})
# (564, {'position': array([25.84725587, 28.06390681]), 'state': 'S_a'})
# (565, {'position': array([28.05228992, 18.97249632]), 'state': 'S_a'})
# (566, {'position': array([ 2.69690955, 23.37987718]), 'state': 'S_a'})
# (567, {'position': array([17.75432414,  1.10002642]), 'state': 'S_a'})
# (568, {'position': array([26.41545361, 17.07119968]), 'state': 'I2_a'})
# (569, {'position': array([17.55907374, 21.19820782]), 'state': 'S_a'})
# (570, {'position': array([12.37721896, 22.42167205]), 'state': 'I2_a'})
# (571, {'position': array([26.20571107, 20.22798962]), 'state': 'S_a'})
# (572, {'position': array([24.16850619,  9.44008393]), 'state': 'S_a'})
# (573, {'position': array([29.30558492, 13.59862231]), 'state': 'S_a'})
# (574, {'position': array([5.67637706, 7.68218575]), 'state': 'S_a'})
# (575, {'position': array([14.01325323, 12.98428049]), 'state': 'S_a'})
# (576, {'position': array([10.94880276, 19.20560865]), 'state': 'S_a'})
# (577, {'position': array([29.55878257, 27.62924532]), 'state': 'S_a'})
# (578, {'position': array([6.46787578, 2.43606136]), 'state': 'S_a'})
# (579, {'position': array([1.33945645, 7.17538081]), 'state': 'S_a'})
# (580, {'position': array([ 8.37069591, 19.9266249 ]), 'state': 'S_a'})
# (581, {'position': array([26.37476571, 14.52620206]), 'state': 'S_a'})
# (582, {'position': array([22.57899615, 20.8135384 ]), 'state': 'S_a'})
# (583, {'position': array([25.80210838, 26.42233325]), 'state': 'S_a'})
# (584, {'position': array([23.50365484, 26.00104159]), 'state': 'S_a'})
# (585, {'position': array([27.82370353, 15.76990851]), 'state': 'S_a'})
# (586, {'position': array([ 4.21899271, 28.92998098]), 'state': 'S_a'})
# (587, {'position': array([ 4.47456768, 16.23720752]), 'state': 'S_a'})
# (588, {'position': array([29.90708713, 25.04094785]), 'state': 'S_a'})
# (589, {'position': array([2.11174749, 5.8514284 ]), 'state': 'S_a'})
# (590, {'position': array([13.14670651, 21.74391775]), 'state': 'I1_a'})
# (591, {'position': array([26.40294715,  3.64482455]), 'state': 'I2_a'})
# (592, {'position': array([14.81455673, 25.07353268]), 'state': 'S_a'})
# (593, {'position': array([ 9.67684339, 22.11046989]), 'state': 'S_a'})
# (594, {'position': array([ 0.97000484, 12.19960112]), 'state': 'S_a'})
# (595, {'position': array([10.03485303, 18.43707067]), 'state': 'S_a'})
# (596, {'position': array([28.7478423 ,  2.63554299]), 'state': 'S_a'})
# (597, {'position': array([10.89422309, 13.46077379]), 'state': 'S_a'})
# (598, {'position': array([ 2.5069956 , 23.00702751]), 'state': 'S_a'})
# (599, {'position': array([ 8.25127701, 19.15331202]), 'state': 'S_a'})
# (600, {'position': array([ 3.85400901, 28.81755894]), 'state': 'S_a'})
# (601, {'position': array([23.806173  ,  4.35250584]), 'state': 'S_a'})
# (602, {'position': array([24.62745779, 10.10968657]), 'state': 'S_a'})
# (603, {'position': array([ 4.97720657, 24.81125572]), 'state': 'S_a'})
# (604, {'position': array([11.36586641,  9.87108401]), 'state': 'S_a'})
# (605, {'position': array([26.71578665,  7.6526591 ]), 'state': 'S_a'})
# (606, {'position': array([28.65579537,  5.33119841]), 'state': 'S_a'})
# (607, {'position': array([ 8.6493218 , 15.58241395]), 'state': 'S_a'})
# (608, {'position': array([17.855976  , 22.04719179]), 'state': 'I2_a'})
# (609, {'position': array([ 3.10351714, 13.7292252 ]), 'state': 'S_a'})
# (610, {'position': array([15.61021137, 24.06388059]), 'state': 'S_a'})
# (611, {'position': array([11.68653616,  6.90226316]), 'state': 'S_a'})
# (612, {'position': array([20.61900206, 11.78700199]), 'state': 'S_a'})
# (613, {'position': array([ 5.68344919, 22.91449175]), 'state': 'S_a'})
# (614, {'position': array([ 4.28635713, 27.69994076]), 'state': 'S_a'})
# (615, {'position': array([26.15720734, 22.2267173 ]), 'state': 'S_a'})
# (616, {'position': array([29.50811359, 24.42883298]), 'state': 'S_a'})
# (617, {'position': array([29.27525241, 24.70358305]), 'state': 'S_a'})
# (618, {'position': array([ 7.86716294, 10.77644948]), 'state': 'S_a'})
# (619, {'position': array([ 4.61793289, 27.27168478]), 'state': 'S_a'})
# (620, {'position': array([ 9.68663525, 16.46403179]), 'state': 'S_a'})
# (621, {'position': array([0.78264026, 6.71652232]), 'state': 'S_a'})
# (622, {'position': array([16.3346248 , 21.83927784]), 'state': 'S_a'})
# (623, {'position': array([16.70604533, 19.31336281]), 'state': 'S_a'})
# (624, {'position': array([1.62144391, 5.23782839]), 'state': 'S_a'})
# (625, {'position': array([0.15896043, 6.21036545]), 'state': 'S_a'})
# (626, {'position': array([ 1.43462942, 26.82218645]), 'state': 'S_a'})
# (627, {'position': array([25.76186368, 20.41978247]), 'state': 'S_a'})
# (628, {'position': array([27.53931957, 18.33638079]), 'state': 'S_a'})
# (629, {'position': array([17.5530624 ,  7.38585434]), 'state': 'S_a'})
# (630, {'position': array([11.45328456,  1.26330184]), 'state': 'S_a'})
# (631, {'position': array([12.42648948, 20.03841428]), 'state': 'S_a'})
# (632, {'position': array([25.68309009, 14.61605289]), 'state': 'S_a'})
# (633, {'position': array([ 1.41102353, 26.20341499]), 'state': 'S_a'})
# (634, {'position': array([ 6.53115112, 10.6181801 ]), 'state': 'S_a'})
# (635, {'position': array([ 1.03606781, 25.87092057]), 'state': 'S_a'})
# (636, {'position': array([23.57087931,  6.56746845]), 'state': 'S_a'})
# (637, {'position': array([24.26111285, 15.21702964]), 'state': 'S_a'})
# (638, {'position': array([19.97722957, 24.34238249]), 'state': 'S_a'})
# (639, {'position': array([5.75000983, 9.44835781]), 'state': 'S_a'})
# (640, {'position': array([22.90621161, 12.25455144]), 'state': 'S_a'})
# (641, {'position': array([16.71828868, 17.91002168]), 'state': 'S_a'})
# (642, {'position': array([23.09933164,  9.81457727]), 'state': 'S_a'})
# (643, {'position': array([ 4.84548462, 15.09023099]), 'state': 'S_a'})
# (644, {'position': array([28.26060308, 23.60645793]), 'state': 'S_a'})
# (645, {'position': array([18.82651886, 27.27961744]), 'state': 'S_a'})
# (646, {'position': array([10.48690245, 14.8189252 ]), 'state': 'S_a'})
# (647, {'position': array([ 1.00475635, 11.02770514]), 'state': 'S_a'})
# (648, {'position': array([19.44930044, 28.18810633]), 'state': 'S_a'})
# (649, {'position': array([25.56960735, 10.4900313 ]), 'state': 'S_a'})
# (650, {'position': array([ 3.88484634, 18.55530371]), 'state': 'S_a'})
# (651, {'position': array([22.98419707, 24.29209292]), 'state': 'S_a'})
# (652, {'position': array([6.42544436, 6.18117564]), 'state': 'S_a'})
# (653, {'position': array([21.94246014, 16.90974257]), 'state': 'S_a'})
# (654, {'position': array([13.11422201, 27.83274088]), 'state': 'S_a'})
# (655, {'position': array([28.95501363, 16.0330228 ]), 'state': 'S_a'})
# (656, {'position': array([17.69572634,  5.59905343]), 'state': 'S_a'})
# (657, {'position': array([ 9.58782241, 11.84045448]), 'state': 'S_a'})
# (658, {'position': array([14.66541557, 12.13155749]), 'state': 'S_a'})
# (659, {'position': array([20.43400815,  1.83001071]), 'state': 'S_a'})
# (660, {'position': array([27.40707174,  1.14250894]), 'state': 'S_a'})
# (661, {'position': array([ 4.89748544, 29.91181727]), 'state': 'S_a'})
# (662, {'position': array([17.23926359,  8.16567612]), 'state': 'S_a'})
# (663, {'position': array([7.77668238, 1.41346491]), 'state': 'S_a'})
# (664, {'position': array([ 0.41975852, 15.63772923]), 'state': 'I1_a'})
# (665, {'position': array([16.00829197, 17.66631121]), 'state': 'S_a'})
# (666, {'position': array([16.80915896,  3.65153155]), 'state': 'S_a'})
# (667, {'position': array([18.98117471,  5.29743622]), 'state': 'S_a'})
# (668, {'position': array([11.93582692, 11.57238374]), 'state': 'S_a'})
# (669, {'position': array([ 6.05149303, 11.19624636]), 'state': 'S_a'})
# (670, {'position': array([19.10176796, 19.06451673]), 'state': 'S_a'})
# (671, {'position': array([15.11445483, 15.91463413]), 'state': 'S_a'})
# (672, {'position': array([2.32357723, 9.88469804]), 'state': 'S_a'})
# (673, {'position': array([ 6.11613897, 23.86036899]), 'state': 'S_a'})
# (674, {'position': array([20.97886931, 25.83299487]), 'state': 'S_a'})
# (675, {'position': array([5.20503664, 2.090305  ]), 'state': 'S_a'})
# (676, {'position': array([ 5.72429575, 18.30952066]), 'state': 'S_a'})
# (677, {'position': array([21.99604654, 27.1302856 ]), 'state': 'S_a'})
# (678, {'position': array([ 2.19920564, 26.00139169]), 'state': 'S_a'})
# (679, {'position': array([14.18843656, 23.14083657]), 'state': 'S_a'})
# (680, {'position': array([ 7.29576184, 21.40996788]), 'state': 'S_a'})
# (681, {'position': array([17.58366455, 24.63944743]), 'state': 'S_a'})
# (682, {'position': array([ 7.21481581, 22.47563949]), 'state': 'S_a'})
# (683, {'position': array([4.52428457, 9.26050662]), 'state': 'S_a'})
# (684, {'position': array([13.13036489, 19.16349923]), 'state': 'S_a'})
# (685, {'position': array([4.3014355 , 7.29772758]), 'state': 'S_a'})
# (686, {'position': array([ 2.49201228, 23.25146047]), 'state': 'S_a'})
# (687, {'position': array([ 6.06914201, 28.45733385]), 'state': 'S_a'})
# (688, {'position': array([28.04792415, 25.79841287]), 'state': 'S_a'})
# (689, {'position': array([ 0.33033452, 26.49490762]), 'state': 'S_a'})
# (690, {'position': array([20.96340138, 11.51020416]), 'state': 'S_a'})
# (691, {'position': array([26.60526404, 18.14912191]), 'state': 'S_a'})
# (692, {'position': array([ 1.94340689, 20.48718537]), 'state': 'S_a'})
# (693, {'position': array([ 8.09464916, 23.30958404]), 'state': 'S_a'})
# (694, {'position': array([25.31579048, 29.40168688]), 'state': 'S_a'})
# (695, {'position': array([ 1.18687809, 23.03802496]), 'state': 'S_a'})
# (696, {'position': array([17.39350628, 16.33580214]), 'state': 'S_a'})
# (697, {'position': array([25.43389388, 20.74652754]), 'state': 'S_a'})
# (698, {'position': array([23.8758297 , 16.43673287]), 'state': 'S_a'})
# (699, {'position': array([12.10374991,  6.34841656]), 'state': 'S_a'})
# (700, {'position': array([ 3.47232538, 27.32102822]), 'state': 'S_a'})
# (701, {'position': array([13.08534358, 24.95360749]), 'state': 'S_a'})
# (702, {'position': array([28.13014141, 27.17180942]), 'state': 'S_a'})
# (703, {'position': array([ 9.53867464, 11.65828105]), 'state': 'S_a'})
# (704, {'position': array([25.05562511,  9.77312156]), 'state': 'S_a'})
# (705, {'position': array([ 3.72115828, 14.93410463]), 'state': 'S_a'})
# (706, {'position': array([19.57245521, 24.12913465]), 'state': 'S_a'})
# (707, {'position': array([18.02346164,  5.22416385]), 'state': 'S_a'})
# (708, {'position': array([27.5363475 ,  2.07201947]), 'state': 'S_a'})
# (709, {'position': array([ 8.54078005, 24.97985273]), 'state': 'S_a'})
# (710, {'position': array([21.61591096,  7.92337909]), 'state': 'S_a'})
# (711, {'position': array([18.34705762, 23.28990171]), 'state': 'S_a'})
# (712, {'position': array([27.22172706,  8.22074231]), 'state': 'S_a'})
# (713, {'position': array([ 1.72931565, 25.74652283]), 'state': 'S_a'})
# (714, {'position': array([16.53362813,  6.19337244]), 'state': 'S_a'})
# (715, {'position': array([16.13555572, 17.37353044]), 'state': 'S_a'})
# (716, {'position': array([21.78556271, 18.54677941]), 'state': 'S_a'})
# (717, {'position': array([14.79640053, 29.28689399]), 'state': 'S_a'})
# (718, {'position': array([10.50942715, 19.00581803]), 'state': 'S_a'})
# (719, {'position': array([ 5.99438885, 20.26553321]), 'state': 'S_a'})
# (720, {'position': array([ 7.18001836, 13.01984815]), 'state': 'S_a'})
# (721, {'position': array([20.05330232, 15.44361329]), 'state': 'S_a'})
# (722, {'position': array([17.97396337,  4.07227817]), 'state': 'S_a'})
# (723, {'position': array([15.73380286,  9.87620044]), 'state': 'S_a'})
# (724, {'position': array([29.23460233, 19.9608689 ]), 'state': 'S_a'})
# (725, {'position': array([28.36898562, 10.52995277]), 'state': 'S_a'})
# (726, {'position': array([ 2.31811126, 13.66701766]), 'state': 'S_a'})
# (727, {'position': array([21.36133849,  4.72142303]), 'state': 'S_a'})
# (728, {'position': array([21.38326687, 20.57954524]), 'state': 'I1_a'})
# (729, {'position': array([7.33860229, 3.57248549]), 'state': 'S_a'})
# (730, {'position': array([25.8557154 ,  9.99317256]), 'state': 'S_a'})
# (731, {'position': array([25.22433189, 22.54200461]), 'state': 'S_a'})
# (732, {'position': array([24.48821673, 10.35823988]), 'state': 'S_a'})
# (733, {'position': array([25.07101963, 12.31687842]), 'state': 'S_a'})
# (734, {'position': array([ 9.29612682, 19.35490439]), 'state': 'S_a'})
# (735, {'position': array([10.75212105, 14.08552665]), 'state': 'S_a'})
# (736, {'position': array([10.0762368 , 22.08329814]), 'state': 'S_a'})
# (737, {'position': array([4.61863875, 4.74067402]), 'state': 'S_a'})
# (738, {'position': array([11.69413225, 20.16769033]), 'state': 'S_a'})
# (739, {'position': array([18.93034985, 18.18882678]), 'state': 'S_a'})
# (740, {'position': array([ 9.24612563, 12.72328824]), 'state': 'S_a'})
# (741, {'position': array([10.79653227, 28.37882267]), 'state': 'S_a'})
# (742, {'position': array([18.71948078, 14.21503965]), 'state': 'I1_a'})
# (743, {'position': array([18.46980085, 23.6217341 ]), 'state': 'S_a'})
# (744, {'position': array([8.32147525, 2.57102389]), 'state': 'S_a'})
# (745, {'position': array([26.87000679,  1.04252821]), 'state': 'S_a'})
# (746, {'position': array([13.12444286, 16.81930618]), 'state': 'S_a'})
# (747, {'position': array([ 5.3364673 , 26.25399538]), 'state': 'I1_a'})
# (748, {'position': array([ 0.97242076, 21.62142733]), 'state': 'S_a'})
# (749, {'position': array([15.81360049,  2.75722841]), 'state': 'S_a'})
# (750, {'position': array([27.18417373,  1.20301602]), 'state': 'S_a'})
# (751, {'position': array([7.00809689, 1.93816902]), 'state': 'S_a'})
# (752, {'position': array([10.08743114,  4.3463124 ]), 'state': 'S_a'})
# (753, {'position': array([ 5.33715829, 14.13146784]), 'state': 'S_a'})
# (754, {'position': array([25.09845802,  6.52258692]), 'state': 'S_a'})
# (755, {'position': array([9.56291899, 8.27959469]), 'state': 'S_a'})
# (756, {'position': array([28.88564224, 25.96562451]), 'state': 'S_a'})
# (757, {'position': array([ 6.16518542, 15.22134716]), 'state': 'S_a'})
# (758, {'position': array([27.67260006, 10.04915568]), 'state': 'S_a'})
# (759, {'position': array([29.05670539,  2.92727053]), 'state': 'S_a'})
# (760, {'position': array([ 6.55568416, 12.47174022]), 'state': 'S_a'})
# (761, {'position': array([26.89305311,  2.69524405]), 'state': 'S_a'})
# (762, {'position': array([28.86245166,  5.18000186]), 'state': 'S_a'})
# (763, {'position': array([ 7.88130629, 22.10001701]), 'state': 'S_a'})
# (764, {'position': array([16.02213919, 15.28820704]), 'state': 'S_a'})
# (765, {'position': array([ 6.05801029, 13.68172963]), 'state': 'S_a'})
# (766, {'position': array([1.3855172 , 9.61027489]), 'state': 'S_a'})
# (767, {'position': array([ 2.17888204, 17.33687427]), 'state': 'S_a'})
# (768, {'position': array([ 9.42138512, 29.33549958]), 'state': 'S_a'})
# (769, {'position': array([28.51941425, 10.53877733]), 'state': 'S_a'})
# (770, {'position': array([13.44646795, 29.8154302 ]), 'state': 'S_a'})
# (771, {'position': array([26.14625714, 12.98996202]), 'state': 'S_a'})
# (772, {'position': array([ 4.62366065, 17.94142317]), 'state': 'S_a'})
# (773, {'position': array([16.68506849, 25.60388101]), 'state': 'S_a'})
# (774, {'position': array([17.72956001, 14.11763448]), 'state': 'I2_a'})
# (775, {'position': array([1.64075742, 1.00975525]), 'state': 'S_a'})
# (776, {'position': array([ 8.88542329, 12.08733413]), 'state': 'S_a'})
# (777, {'position': array([18.28302735, 17.17641668]), 'state': 'S_a'})
# (778, {'position': array([3.54363585, 9.34524219]), 'state': 'S_a'})
# (779, {'position': array([28.58318759, 26.43430148]), 'state': 'S_a'})
# (780, {'position': array([23.33059209, 25.04405629]), 'state': 'S_a'})
# (781, {'position': array([16.9373084 , 14.42620725]), 'state': 'S_a'})
# (782, {'position': array([ 8.66044411, 24.5681043 ]), 'state': 'S_a'})
# (783, {'position': array([6.40546802, 1.78464821]), 'state': 'S_a'})
# (784, {'position': array([7.32426805, 5.54164616]), 'state': 'S_a'})
# (785, {'position': array([29.5624986, 11.4685643]), 'state': 'S_a'})
# (786, {'position': array([4.31580431, 3.06477798]), 'state': 'S_a'})
# (787, {'position': array([22.28223728, 17.50863689]), 'state': 'S_a'})
# (788, {'position': array([3.59993467, 7.1684506 ]), 'state': 'S_a'})
# (789, {'position': array([5.42920997, 5.70294225]), 'state': 'S_a'})
# (790, {'position': array([ 9.65441847, 25.03743554]), 'state': 'S_a'})
# (791, {'position': array([4.94137847, 0.73433229]), 'state': 'S_a'})
# (792, {'position': array([ 0.74224108, 15.59206328]), 'state': 'S_a'})
# (793, {'position': array([3.66984209, 5.93960625]), 'state': 'S_a'})
# (794, {'position': array([22.96018982, 22.98742033]), 'state': 'S_a'})
# (795, {'position': array([24.2114527, 17.6594947]), 'state': 'S_a'})
# (796, {'position': array([12.65957141, 21.86802276]), 'state': 'S_a'})
# (797, {'position': array([27.21367942, 15.96388023]), 'state': 'S_a'})
# (798, {'position': array([13.17557896,  8.44364327]), 'state': 'S_a'})
# (799, {'position': array([12.45550962,  8.82287823]), 'state': 'S_a'})
# (800, {'position': array([16.86091589,  7.1258593 ]), 'state': 'S_a'})
# (801, {'position': array([ 3.52030757, 24.92454404]), 'state': 'S_a'})
# (802, {'position': array([13.979214  ,  3.41874489]), 'state': 'S_a'})
# (803, {'position': array([11.47932384, 22.35054992]), 'state': 'S_a'})
# (804, {'position': array([20.38348847,  8.62857669]), 'state': 'S_a'})
# (805, {'position': array([ 3.54489123, 12.1899867 ]), 'state': 'S_a'})
# (806, {'position': array([12.70560744, 15.46410552]), 'state': 'S_a'})
# (807, {'position': array([25.73553626, 28.88324806]), 'state': 'S_a'})
# (808, {'position': array([23.54561957, 17.93939453]), 'state': 'S_a'})
# (809, {'position': array([8.19226295, 5.89933242]), 'state': 'S_a'})
# (810, {'position': array([ 4.11730728, 24.98332249]), 'state': 'S_a'})
# (811, {'position': array([ 6.62358349, 19.63091559]), 'state': 'S_a'})
# (812, {'position': array([1.4367549 , 8.18069458]), 'state': 'S_a'})
# (813, {'position': array([19.83428961, 25.37408364]), 'state': 'S_a'})
# (814, {'position': array([9.26423107, 4.87964419]), 'state': 'S_a'})
# (815, {'position': array([ 2.28982182, 23.7261952 ]), 'state': 'S_a'})
# (816, {'position': array([ 7.30405701, 13.84252495]), 'state': 'S_a'})
# (817, {'position': array([27.54081266, 19.38595124]), 'state': 'S_a'})
# (818, {'position': array([0.48750204, 3.65496284]), 'state': 'S_a'})
# (819, {'position': array([1.8447154 , 4.48743738]), 'state': 'S_a'})
# (820, {'position': array([13.55526031, 27.65572959]), 'state': 'S_a'})
# (821, {'position': array([12.16801454, 22.41225981]), 'state': 'S_a'})
# (822, {'position': array([16.2235067 , 20.84371688]), 'state': 'I1_a'})
# (823, {'position': array([8.61277846, 9.38687717]), 'state': 'S_a'})
# (824, {'position': array([17.66990897, 23.82467707]), 'state': 'S_a'})
# (825, {'position': array([28.19702006, 12.52818088]), 'state': 'I2_a'})
# (826, {'position': array([1.33605727, 5.30530898]), 'state': 'S_a'})
# (827, {'position': array([29.42878986, 28.29626792]), 'state': 'S_a'})
# (828, {'position': array([22.53166154,  5.15365348]), 'state': 'S_a'})
# (829, {'position': array([20.15963247, 18.76851976]), 'state': 'S_a'})
# (830, {'position': array([27.41808827, 21.40398947]), 'state': 'S_a'})
# (831, {'position': array([21.6476452 , 20.92651826]), 'state': 'S_a'})
# (832, {'position': array([28.75198469, 10.38192375]), 'state': 'S_a'})
# (833, {'position': array([24.05360806, 29.14075568]), 'state': 'S_a'})
# (834, {'position': array([ 6.42267993, 13.64216526]), 'state': 'S_a'})
# (835, {'position': array([19.25814221,  2.19640862]), 'state': 'S_a'})
# (836, {'position': array([25.68242226, 25.97784853]), 'state': 'S_a'})
# (837, {'position': array([13.54386246,  1.06756427]), 'state': 'S_a'})
# (838, {'position': array([12.54776951, 21.2250356 ]), 'state': 'S_a'})
# (839, {'position': array([24.1689517 , 22.10196768]), 'state': 'I1_a'})
# (840, {'position': array([24.4831335 , 24.56852353]), 'state': 'S_a'})
# (841, {'position': array([3.14703063, 0.97764275]), 'state': 'S_a'})
# (842, {'position': array([4.48318775, 7.78442899]), 'state': 'S_a'})
# (843, {'position': array([22.78291876,  6.8474763 ]), 'state': 'S_a'})
# (844, {'position': array([ 4.65730471, 23.78028936]), 'state': 'S_a'})
# (845, {'position': array([29.80831004,  9.53801897]), 'state': 'S_a'})
# (846, {'position': array([12.56141455,  7.51554095]), 'state': 'I2_a'})
# (847, {'position': array([20.27259715,  4.47663496]), 'state': 'S_a'})
# (848, {'position': array([ 6.42386004, 10.53107255]), 'state': 'S_a'})
# (849, {'position': array([ 4.75588656, 11.53888373]), 'state': 'S_a'})
# (850, {'position': array([16.32024262, 27.32108322]), 'state': 'S_a'})
# (851, {'position': array([ 3.54013671, 27.62835967]), 'state': 'S_a'})
# (852, {'position': array([ 8.98488947, 17.68912543]), 'state': 'S_a'})
# (853, {'position': array([ 3.42713571, 16.52741199]), 'state': 'S_a'})
# (854, {'position': array([15.72897833, 16.89206815]), 'state': 'S_a'})
# (855, {'position': array([3.89917391, 8.28168008]), 'state': 'S_a'})
# (856, {'position': array([ 6.132597  , 26.09850279]), 'state': 'S_a'})
# (857, {'position': array([21.66504031, 19.67693812]), 'state': 'S_a'})
# (858, {'position': array([22.46140272,  8.96251137]), 'state': 'I2_a'})
# (859, {'position': array([ 9.32333581, 25.14350771]), 'state': 'S_a'})
# (860, {'position': array([22.30691137, 19.25672332]), 'state': 'S_a'})
# (861, {'position': array([22.70762489, 15.94215765]), 'state': 'S_a'})
# (862, {'position': array([19.91651223, 26.9734592 ]), 'state': 'S_a'})
# (863, {'position': array([ 2.55579458, 14.55024838]), 'state': 'S_a'})
# (864, {'position': array([ 5.32357273, 26.50341482]), 'state': 'S_a'})
# (865, {'position': array([20.63749519, 18.24146825]), 'state': 'S_a'})
# (866, {'position': array([27.12328077, 12.13069956]), 'state': 'I1_a'})
# (867, {'position': array([18.33017279,  5.75668179]), 'state': 'S_a'})
# (868, {'position': array([18.2413391 , 29.56639561]), 'state': 'S_a'})
# (869, {'position': array([29.85410494, 27.46205588]), 'state': 'S_a'})
# (870, {'position': array([19.06303534,  3.27068051]), 'state': 'S_a'})
# (871, {'position': array([17.58327771, 15.85838467]), 'state': 'S_a'})
# (872, {'position': array([26.24100543, 27.66807794]), 'state': 'S_a'})
# (873, {'position': array([14.24488721,  6.27698202]), 'state': 'S_a'})
# (874, {'position': array([20.07877675, 21.95675512]), 'state': 'S_a'})
# (875, {'position': array([25.88037454, 20.25656728]), 'state': 'S_a'})
# (876, {'position': array([17.48484473, 28.1394363 ]), 'state': 'S_a'})
# (877, {'position': array([29.29878713, 15.09291623]), 'state': 'I2_a'})
# (878, {'position': array([ 8.61610937, 10.1611488 ]), 'state': 'S_a'})
# (879, {'position': array([19.92920855, 29.8424582 ]), 'state': 'S_a'})
# (880, {'position': array([11.39973826, 25.63487213]), 'state': 'S_a'})
# (881, {'position': array([14.6584246 , 20.65312311]), 'state': 'S_a'})
# (882, {'position': array([ 1.30976199, 17.69399459]), 'state': 'S_a'})
# (883, {'position': array([29.65645273, 21.16324757]), 'state': 'S_a'})
# (884, {'position': array([ 0.34778122, 15.41753433]), 'state': 'S_a'})
# (885, {'position': array([14.31319907, 21.98544142]), 'state': 'S_a'})
# (886, {'position': array([20.0673307 , 24.07826022]), 'state': 'S_a'})
# (887, {'position': array([ 5.25915646, 17.95238507]), 'state': 'S_a'})
# (888, {'position': array([23.54497067, 17.79862784]), 'state': 'S_a'})
# (889, {'position': array([22.61361393, 14.15376101]), 'state': 'S_a'})
# (890, {'position': array([14.95205155, 10.76697159]), 'state': 'S_a'})
# (891, {'position': array([11.69047805, 26.29658049]), 'state': 'S_a'})
# (892, {'position': array([20.88547766, 25.46222262]), 'state': 'I1_a'})
# (893, {'position': array([ 8.82625998, 23.73429697]), 'state': 'S_a'})
# (894, {'position': array([10.63341766, 13.21980525]), 'state': 'S_a'})
# (895, {'position': array([1.29525221, 8.24374855]), 'state': 'S_a'})
# (896, {'position': array([8.75311008, 2.76297201]), 'state': 'S_a'})
# (897, {'position': array([17.48271445, 28.74589841]), 'state': 'S_a'})
# (898, {'position': array([29.11408959, 18.58359257]), 'state': 'S_a'})
# (899, {'position': array([22.1241356 ,  5.71556089]), 'state': 'S_a'})

# %%
nod = a.G.node[0]
# nod['state'] = 'I1_a'
diag.next(a.G, 0)
a.G.node[0]['state'] = a.G.node[0]['next_state']
a.G.node[0]
# Out:
# {'state': 'S_a',
#  'position': array([0.79454763, 6.50435499]),
#  'next_state': 'S_a'}

# %%
uniform(0,[10,1],2)
randint(0, 100,10)
s= sample(range(20), 10)
# print(s[:5], s[5:])
print(s)
del s[1]
s
# Out:
# [10, 9, 6, 3, 7, 11, 0, 12, 8, 2]
# [10, 6, 3, 7, 11, 0, 12, 8, 2]

# %%
paramet = {
        'alpha': [0.03, 0.06], # infect rate 
        'mu': [0.14, 0.14], # sleep s 
        'gamma': [0.35, 0.47], # rec rate 
        'lambda': [0.05, 0.32], # sleep I1 
        'kappa': [0.04, 0.31] # sleep I2    % [I2_s -> I2_a, I2_a -> I2_s]
    }

def dist(pos1,pos2):
#     return math.sqrt((pos1-pos2))
    return np.linalg.norm(pos1-pos2)

dist(np.array([0,0]), np.array([0,1]))
# Out:
# 1.0

# %%
transitions = {
            'S_a': {
                'S_s': paramet['mu'][1],
                'I1_a': paramet['alpha'][0],
                'I2_a': paramet['alpha'][1]
            },
            'S_s': {
                'S_a': paramet['mu'][0]
            },
            'I1_a': {
                'S_a': paramet['gamma'][0],
                'I1_s': paramet['lambda'][1]
            },
            'I1_s': {
                'I1_a': paramet['lambda'][0]
            },
            'I2_a': {
                'S_a': paramet['gamma'][1],
                'I2_s': paramet['kappa'][1]
            },
            'I2_s':{
                'I2_a': paramet['kappa'][0]
            }
        }
transitions
# Out:
# {'S_a': {'S_s': 0.14, 'I1_a': 0.03, 'I2_a': 0.06},
#  'S_s': {'S_a': 0.14},
#  'I1_a': {'S_a': 0.35, 'I1_s': 0.32},
#  'I1_s': {'I1_a': 0.05},
#  'I2_a': {'S_a': 0.47, 'I2_s': 0.31},
#  'I2_s': {'I2_a': 0.04}}

# %%
[x for x, y in a.G.nodes(data=True) if y['state']=='S_a']
population_count = {
            'S_a':  10,
            'S_s':  0,
            'I1_a': 0,
            'I1_s': 0,
            'I2_a': 0,
            'I2_s': 0
        }
def foo(v):
            if v < 0:
                return False
            else:
                return True
all([foo(v) for v in population_count.values()])
# Out:
# True

# %%
from pymatbridge import Matlab
# mlab = Matlab(executable='C:\Program Files\MATLAB\MATLAB Production Server\R2015a\bin\matlab')
mlab = Matlab(executable='matlab')

mlab.start()
# Out:
# Starting MATLAB on ZMQ socket tcp://127.0.0.1:6461
# Send 'exit' command to kill the server
# .......MATLAB started and connected!

# %%
res = mlab.run_func('main_main.m', {'arg1': 3, 'arg2': 5})
# res = mlab.run_code('a=1')
print(res['result'])
res
mlab.run_func()
# Out:
# {'content': {'stdout': 'Attempt to execute SCRIPT main_main as a function:\nA:\\Dropbox\\8th\\Capstone\\Epidemic-Model\\epidemic_3\\main_main.m'},
#  'result': '',
#  'success': False}

# %%
res = mlab.run_code(
'''
RunTime = 300;
monte_rounds = 5;
dim = [30,30]; 
global I1a_Initial I2a_Initial N dt 
N = dim(1)*dim(2);
I1a_Initial = 10; %I1_A_Initial 
I2a_Initial = 10; %I2_A_Initial 
dt = 0.05;

global alpha mu gamma lambda kappa
alpha = [0.03, 0.06]; % infect rate 
mu = [0.14, 0.14]; % sleep s 
gamma = [0.35, 0.47]; % rec rate 
lambda = [0.05, 0.32]; % sleep I1 
kappa = [0.04, 0.31]; % sleep I2    % [I2_s -> I2_a, I2_a -> I2_s]

r0=3;
Net2 = NetGen_Geo(N,r0,dim);
NetRnd = NetCmbn({Net2, Net2});
[R0_rnd,R1_rnd,R2_rnd] = calc_R0(NetRnd, alpha, mu, gamma, lambda, kappa, N);
[R1_rnd;R2_rnd]
%% Monte Dima
x0_rnd = Initial_Cond_Gen(N,'Population',[3,5],[I1a_Initial,I2a_Initial]);
Para = Para_active_sleep_SI1I2S(alpha, mu, gamma, lambda, kappa); 
M = Para{1}; 
StopCond={'RunTime', RunTime};

[t, rnd_stch] = monte_new(monte_rounds,N,Para,NetRnd,x0_rnd,StopCond,I1a_Initial,I2a_Initial);
''')
res
# Out:
# {'content': {'stdout': '\r\nR11 =\r\n\r\n    0.8699\r\n\r\n\r\nR21 =\r\n\r\n    1.4227\r\n\r\n\r\nans =\r\n\r\n    0.8770\r\n    1.4298\r\n\r\nElapsed time is 4.007603 seconds.\r\nElapsed time is 3.916985 seconds.\r\nElapsed time is 3.951945 seconds.\r\nElapsed time is 3.763409 seconds.\r\nElapsed time is 3.791015 seconds.\r\n',
#   'figures': [],
#   'datadir': 'C:\\Users\\DFed\\AppData\\Local\\Temp\\MatlabData\\'},
#  'result': [],
#  'success': True}

# %%
rnd_stch = mlab.get_variable('rnd_stch')
t = mlab.get_variable('t')
# res = mlab.run_func('main_main.m', {'arg1': 3, 'arg2': 5})

# %%
import matplotlib.pyplot as plt

plt.plot(t, rnd_stch.T)
plt.show()
